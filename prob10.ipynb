# %%
import matplotlib.pyplot as plt
import numpy
import physics

out = physics.simulate_auv2_motion(numpy.array([10,10,5,3]), numpy.pi/4, 2,2, t_final = 4)
plt.plot(out[1], out[2], label="Position")
plt.xlabel("Position (X)")
plt.ylabel("Position (Y)")
plt.legend()
plt.show()
